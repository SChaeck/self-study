# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-v0_8') # seaborn 스타일
sns.set(font_scale=2.5)  # font scale는 2.5

import missingno as msno

# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df_train = pd.read_csv('../input/titanic/train.csv')
df_test = pd.read_csv('../input/titanic/test.csv')

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %%
for col in df_train.columns:
    msg = 'column: {:>11}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:    Survived	 Percent of NaN value: 0.00%
# column:      Pclass	 Percent of NaN value: 0.00%
# column:        Name	 Percent of NaN value: 0.00%
# column:         Sex	 Percent of NaN value: 0.00%
# column:         Age	 Percent of NaN value: 19.87%
# column:       SibSp	 Percent of NaN value: 0.00%
# column:       Parch	 Percent of NaN value: 0.00%
# column:      Ticket	 Percent of NaN value: 0.00%
# column:        Fare	 Percent of NaN value: 0.00%
# column:       Cabin	 Percent of NaN value: 77.10%
# column:    Embarked	 Percent of NaN value: 0.22%

# %%
#df_train[col].isnull().sum() # null -> True -> 1 => 모두 더하면 null data의 개수

# %%
#df_train[col].isnull().sum() / df_train[col].shape[0]

# %%
for col in df_test.columns:
    msg = 'column: {:>11}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:      Pclass	 Percent of NaN value: 0.00%
# column:        Name	 Percent of NaN value: 0.00%
# column:         Sex	 Percent of NaN value: 0.00%
# column:         Age	 Percent of NaN value: 20.57%
# column:       SibSp	 Percent of NaN value: 0.00%
# column:       Parch	 Percent of NaN value: 0.00%
# column:      Ticket	 Percent of NaN value: 0.00%
# column:        Fare	 Percent of NaN value: 0.24%
# column:       Cabin	 Percent of NaN value: 78.23%
# column:    Embarked	 Percent of NaN value: 0.00%

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8,8), color=(0.2, 0.5, 0.2))
# Out:
# <Axes: >

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8,8), color=(0.2, 0.5, 0.2))
# Out:
# <Axes: >

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8)) # 팔레트 깔고, 1행 2열, 그림 크기는 가로 18, 세로 8

df_train['Survived'].value_counts().plot.pie(explode=[0, 0.1], autopct='%1.1f%%', ax=ax[0], shadow=True)
# 생존자 밸류(숫자)를 세고, plot()으로 함수를 그리고, 생긴 함수를 파이로 변경 (매개변수: explode(거리 벌리기), autopct(퍼센트), ax(0번째열에 넣는다.), 그림자 줘)

ax[0].set_title('Pie plot - Survived')
ax[0].set_ylabel('') # ylabel 없애기

sns.countplot(x='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Count plot = Survived')
plt.show()

# target label이 인밸런스하지 않고 밸런스돼 있다.

# %% [markdown]
# ## 2.1 Pclass

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass']).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True).style.background_gradient(cmap="cool")
# Out:
# <style type="text/css">
# #T_6c2b6_row0_col0, #T_6c2b6_row1_col1, #T_6c2b6_row1_col2 {
#   background-color: #00ffff;
#   color: #000000;
# }
# #T_6c2b6_row0_col1 {
#   background-color: #31ceff;
#   color: #000000;
# }
# #T_6c2b6_row0_col2 {
#   background-color: #0bf4ff;
#   color: #000000;
# }
# #T_6c2b6_row1_col0 {
#   background-color: #09f6ff;
#   color: #000000;
# }
# #T_6c2b6_row2_col0 {
#   background-color: #9f60ff;
#   color: #f1f1f1;
# }
# #T_6c2b6_row2_col1 {
#   background-color: #20dfff;
#   color: #000000;
# }
# #T_6c2b6_row2_col2 {
#   background-color: #6f90ff;
#   color: #f1f1f1;
# }
# #T_6c2b6_row3_col0, #T_6c2b6_row3_col1, #T_6c2b6_row3_col2 {
#   background-color: #ff00ff;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c2b6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_6c2b6_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_6c2b6_level0_col1" class="col_heading level0 col1" >1</th>
# ...

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).mean().sort_values(by="Survived", ascending=False).plot.bar()
# Out:
# <Axes: xlabel='Pclass'>

# %%
y_position = 1.02
f, ax = plt.subplots(1, 2, figsize=(18, 8))
#df_train['Pclass'].value_counts().plot.pie(explode=[0.05, 0.05, 0.05], autopct='%1.1f%%', ax=ax[0], shadow=True)
df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32', '#FFDF00', '#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of apssengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')
sns.countplot(x='Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass: Survived vs Dead', y=y_position)
plt.show()

# %% [markdown]
# ## 2.2 Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot(x = 'Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True).style.background_gradient(cmap="summer_r")
# Out:
# <style type="text/css">
# #T_3a4e7_row0_col0, #T_3a4e7_row0_col2, #T_3a4e7_row1_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_3a4e7_row0_col1 {
#   background-color: #77bb66;
#   color: #f1f1f1;
# }
# #T_3a4e7_row1_col0 {
#   background-color: #2c9666;
#   color: #f1f1f1;
# }
# #T_3a4e7_row1_col2 {
#   background-color: #8bc566;
#   color: #000000;
# }
# #T_3a4e7_row2_col0, #T_3a4e7_row2_col1, #T_3a4e7_row2_col2 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3a4e7">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Survived</th>
#       <th id="T_3a4e7_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_3a4e7_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_3a4e7_level0_col2" class="col_heading level0 col2" >All</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Sex</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %% [markdown]
# ### 2.2 Both Sex and Pclass

# %%
sns.catplot(x='Pclass', y='Survived', hue="Sex", data=df_train, kind='point', height=6, aspect=1.5)

# %%
#sns.catplot(x="Sex", y="Survived", col="Pclass", data=df_train, kind='point', height=9, aspect=1)
sns.catplot(x="Sex", y="Survived", hue="Pclass", data=df_train, kind='point', height=9, aspect=1)

# %% [markdown]
# ## Age

# %%
print('제일 나이 많은 탑승객: {:.1f} years'.format(df_train['Age'].max()))
print('제일 어린 탑승객: {:.1f} years'.format(df_train['Age'].min()))
print('탑승객 평균 나이: {:.1f} years'.format(df_train['Age'].mean()))
# Out:
# 제일 나이 많은 탑승객: 80.0 years
# 제일 어린 탑승객: 0.4 years
# 탑승객 평균 나이: 29.7 years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[df_train['Survived'] == 1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived'] == 0]['Age'], ax=ax)
plt.legend(['Survived == 1', 'Survived == 0'])
plt.show()

# %%
df_train[df_train['Survived'] == 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df_train[df_train['Survived'] == 1]['Age'].hist()
# Out:
# <Axes: >

# %%
f = plt.figure(figsize=(5, 5))

ax = plt.subplot(1, 1, 1)

plt.figure(figsize=(5, 5))

# %%
#f = plt.figure(figsize=(10, 10))
f, ax = plt.subplots(1, 1, figsize=(5, 5))
a = np.arange(100)
b = np.sin(a)

ax.plot(b)

# %%
#f = plt.figure(figsize=(10, 10))
plt.figure(figsize=(5, 5))
a = np.arange(100)
b = np.sin(a)

plt.plot(b)

# %%
plt.figure(figsize=(8, 6))
df_train['Age'][df_train['Pclass'] == 1].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 2].plot(kind='kde')
df_train['Age'][df_train['Pclass'] == 3].plot(kind='kde')

#df_train['Age'][df_train['Pclass'] == 1].plot(kind='hist')
#df_train['Age'][df_train['Pclass'] == 2].plot(kind='hist')
#df_train['Age'][df_train['Pclass'] == 3].plot(kind='hist')


plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 1)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 1)]['Age'], ax=ax)
plt.legend(['Survived == 0', 'Survived == 1'])
plt.title('1st class')
plt.show()
# 그림이 0을 넘어가는 이유 => 아래 히스토그램을 스무스하게 근사하려다보니 0을 넘어가게 되는 것!

# %%
plt.figure(figsize=(8, 6))
df_train['Age'][(df_train['Pclass'] == 1) & (df_train['Survived'] == 0)].plot(kind='hist')
df_train['Age'][(df_train['Pclass'] == 1) & (df_train['Survived'] == 1)].plot(kind='hist')


plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class'])

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 2)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 2)]['Age'], ax=ax)
plt.legend(['Survived == 0', 'Survived == 1'])
plt.title('2nd class')
plt.show()

# %%
fig, ax = plt.subplots(1, 1, figsize=(9, 5))
sns.kdeplot(df_train[(df_train['Survived'] == 0) & (df_train['Pclass'] == 3)]['Age'], ax=ax)
sns.kdeplot(df_train[(df_train['Survived'] == 1) & (df_train['Pclass'] == 3)]['Age'], ax=ax)
plt.legend(['Survived == 0', 'Survived == 1'])
plt.title('3rd class')
plt.show()

# %%
change_age_range_survival_ratio = []

for i  in range(1, 80):
    change_age_range_survival_ratio.append(df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived']))
    
plt.figure(figsize=(7,7))
plt.plot(change_age_range_survival_ratio)
plt.title('Survival rate change depending on range of Age', y=1.02)
plt.ylabel('Survival rate')
plt.xlabel('Range of Age(0-x)')
plt.show()

# %%
i = 10
df_train[df_train['Age'] < i]['Survived'].sum() / len(df_train[df_train['Age'] < i]['Survived'])
# Out:
# 0.6129032258064516

# %%
df_train[df_train['Age'] < i]['Survived'].sum()
# Out:
# 38

# %% [markdown]
# ## Pclass, Sex, Age

# %%
f, ax = plt.subplots(1, 2, figsize=(18, 8))
sns.violinplot(x='Pclass', y='Age', hue='Survived', data=df_train, scale='area', split=True, ax=ax[0])
# scale - count: 실제 데이터의 개수 / area: 넓이를 같게하여 분포 
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 20))

sns.violinplot(x='Sex', y='Age', hue='Survived', data=df_train, scale='count', split=False, ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %% [markdown]
# ## Embarked

# %%
f, ax = plt.subplots(1, 1, figsize=(7, 7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)
# Out:
# <Axes: xlabel='Embarked'>

# %%
f, ax = plt.subplots(2, 2, figsize=(20, 15))
sns.countplot(x='Embarked', data=df_train, ax=ax[0, 0])
ax[0, 0].set_title('(1) No. Of Passengers Boared')

sns.countplot(x='Embarked', hue='Sex', data=df_train, ax=ax[0, 1])
ax[0, 1].set_title('(2) Male-Female split for embarked')

sns.countplot(x='Embarked', hue='Survived', data=df_train, ax=ax[1, 0])
ax[1, 0].set_title('(3) Embarked vs Survived')

sns.countplot(x='Embarked', hue='Pclass', data=df_train, ax=ax[1, 1])
ax[1, 1].set_title('(4) Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5) # 공백 추가
plt.show()

# %% [markdown]
# ## Family - SibSp + Parch

# %%
df_train['FamilySize'] = df_train['SibSp'] + df_train['Parch'] + 1
df_test['FamilySize'] = df_test['SibSp'] + df_test['Parch'] + 1

# %%
df_train['FamilySize']
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64

# %%
print('Maximum size of Family: ', df_train['FamilySize'].max())
print('Minimum size of Family: ', df_train['FamilySize'].min())
# Out:
# Maximum size of Family:  11
# Minimum size of Family:  1

# %%
f, ax = plt.subplots(1, 3, figsize=(40, 10))
sns.countplot(x='FamilySize', data=df_train, ax=ax[0])
ax[0].set_title('(1) No. Of Passenger Boarded', y=1.02)

sns.countplot(x='FamilySize', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('(2) Survived countplot depending on FamilySize', y=1.02)

df_train[['FamilySize', 'Survived']].groupby(['FamilySize'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax[2])
ax[2].set_title('(3) Survived rate depending on FamilySize', y=1.02)

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# ## Fare

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness: {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
# distplot은 히스토그램을 그려준다. // Skewness -> 왜도 
# 좌측으로 많이 치우쳐져 있어 그대로 학습에 사용하면 모델의 성능이 안좋아질 수 있음.
g = g.legend(loc='best')

# %%
df_train['Fare'] = df_train['Fare'].map(lambda i: np.log(i) if i > 0 else 0) # i가 0보다 크면 log를 취하고, 0보다 작으면 0을 준다.
# feature engineering => 모델의 성능을 향상하기 위해서, feature를 조작하는 것

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
g = sns.distplot(df_train['Fare'], color='b', label='Skewness: {:.2f}'.format(df_train['Fare'].skew()), ax=ax)
# distplot은 히스토그램을 그려준다. // Skewness -> 왜도 
# 좌측으로 많이 치우쳐져 있어 그대로 학습에 사용하면 모델의 성능이 안좋아질 수 있음.
g = g.legend(loc='best')

# %%
df_train['Ticket'].value_counts() # 티켓과 캐빈은 패스 ; 캐빈은 널값이 너무 많고, 티켓은 튜토리얼 끝나고 혼자 공부해서 성능 향상에 써보라
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
#            ..
# 9234        1
# 19988       1
# 2693        1
# PC 17612    1
# 370376      1
# Name: count, Length: 681, dtype: int64

# %% [markdown]
# # Feature Engneering:
# - 정형적인 데이터를 학습하기 쉽도록 만들어줌

# %%
df_train['Age'].isnull().sum()
# null 값이 177개... 
# 방법 1. null 항목을 평균값으로 채우기 (통계적으로 채우기)
# 방법 2. 층으로 나누어서 각 층의 평균값으로 채우기 (통계적으로 채우기)
# ...
# Out:
# 177

# %%
df_train['Age'].mean()
# Out:
# 29.69911764705882

# %%
df_train['Initial'] = df_train['Name'].str.extract('([A-Za-z]+)\.') # 알파벳 여러개에 마지막 .이 붙는 것 -> 정규 표현식도 공부해야 할듯.
df_test['Initial'] = df_test['Name'].str.extract('([A-Za-z]+)\.') # 알파벳 여러개에 마지막 .이 붙는 것 -> 정규 표현식도 공부해야 할듯.

# %%
pd.crosstab(df_train['Initial'], df_train['Sex']).T.style.background_gradient(cmap='summer_r')
# Out:
# <style type="text/css">
# #T_45db1_row0_col0, #T_45db1_row0_col1, #T_45db1_row0_col3, #T_45db1_row0_col4, #T_45db1_row0_col5, #T_45db1_row0_col7, #T_45db1_row0_col8, #T_45db1_row0_col12, #T_45db1_row0_col15, #T_45db1_row0_col16, #T_45db1_row1_col2, #T_45db1_row1_col6, #T_45db1_row1_col9, #T_45db1_row1_col10, #T_45db1_row1_col11, #T_45db1_row1_col13, #T_45db1_row1_col14 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_45db1_row0_col2, #T_45db1_row0_col6, #T_45db1_row0_col9, #T_45db1_row0_col10, #T_45db1_row0_col11, #T_45db1_row0_col13, #T_45db1_row0_col14, #T_45db1_row1_col0, #T_45db1_row1_col1, #T_45db1_row1_col3, #T_45db1_row1_col4, #T_45db1_row1_col5, #T_45db1_row1_col7, #T_45db1_row1_col8, #T_45db1_row1_col12, #T_45db1_row1_col15, #T_45db1_row1_col16 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_45db1">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Initial</th>
# ...

# %%
df_train['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don', 'Dona'],
                           ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr', 'Mr'], inplace=True)
# inplace=True 해야 값이 바뀜

df_test['Initial'].replace(['Mlle', 'Mme', 'Ms', 'Dr', 'Major', 'Lady', 'Countess', 'Jonkheer', 'Col', 'Rev', 'Capt', 'Sir', 'Don', 'Dona'],
                           ['Miss', 'Miss', 'Miss', 'Mr', 'Mr', 'Mrs', 'Mrs', 'Other', 'Other', 'Other', 'Mr', 'Mr', 'Mr', 'Mr'], inplace=True)

# %%
df_train.groupby('Initial')[['Age', 'Fare']].mean()
# Out:
#                Age      Fare
# Initial
# Master    4.574167  3.340710
# Miss     21.860000  3.123713
# Mr       32.739609  2.651507
# Mrs      35.981818  3.443751
# Other    45.888889  2.641605

# %%
df_train.groupby('Initial')['Survived'].mean().plot.bar()
# Out:
# <Axes: xlabel='Initial'>

# %%
# null을 채울 때 train과 test를 같이 할건지 따로 할건지
# 정답은 train에서 채운 방법으로 test를 채우는 것
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Mr'), 'Age'] = 33
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Mrs'), 'Age'] = 36
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Master'), 'Age'] = 5
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Miss'), 'Age'] = 22
df_train.loc[(df_train['Age'].isnull()) & (df_train['Initial'] == 'Others'), 'Age'] = 46

# %%
df_train.loc[(df_train['Initial'] == 'Mr'), 'Age'].isnull().sum()
# Out:
# 0

# %%
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Mr'), 'Age'] = 33
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Mrs'), 'Age'] = 36
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Master'), 'Age'] = 5
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Miss'), 'Age'] = 22
df_test.loc[(df_test['Age'].isnull()) & (df_test['Initial'] == 'Others'), 'Age'] = 46

# %%
df_train['Embarked'].isnull().sum()
# 2개 밖에 안되고, 전체 데이터가 891개이므로 그냥 최빈값으로 채워버리기
# Out:
# 2

# %%
df_train.shape
# Out:
# (891, 14)

# %%
df_train['Embarked'].fillna('S', inplace=True)

# %%
df_train['Embarked'].isnull().sum()
# Out:
# 0

# %%
df_train['Age_cat'] = 0

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Cabin Embarked  FamilySize Initial  \
# 0      0         A/5 21171  1.981001   NaN        S           2      Mr
# 1      0          PC 17599  4.266662   C85        C           2     Mrs
# 2      0  STON/O2. 3101282  2.070022   NaN        S           1    Miss
# ...

# %%
df_train.loc[df_train['Age'] < 10, 'Age_cat'] = 0
df_train.loc[(10 <= df_train['Age']) & (df_train['Age'] < 20), 'Age_cat'] = 1
df_train.loc[(20 <= df_train['Age']) & (df_train['Age'] < 30), 'Age_cat'] = 2
df_train.loc[(30 <= df_train['Age']) & (df_train['Age'] < 40), 'Age_cat'] = 3
df_train.loc[(40 <= df_train['Age']) & (df_train['Age'] < 50), 'Age_cat'] = 4
df_train.loc[(50 <= df_train['Age']) & (df_train['Age'] < 60), 'Age_cat'] = 5
df_train.loc[(60 <= df_train['Age']) & (df_train['Age'] < 70), 'Age_cat'] = 6
df_train.loc[(70 <= df_train['Age']), 'Age_cat'] = 7

# %%
df_test.loc[df_test['Age'] < 10, 'Age_cat'] = 0
df_test.loc[(10 <= df_test['Age']) & (df_test['Age'] < 20), 'Age_cat'] = 1
df_test.loc[(20 <= df_test['Age']) & (df_test['Age'] < 30), 'Age_cat'] = 2
df_test.loc[(30 <= df_test['Age']) & (df_test['Age'] < 40), 'Age_cat'] = 3
df_test.loc[(40 <= df_test['Age']) & (df_test['Age'] < 50), 'Age_cat'] = 4
df_test.loc[(50 <= df_test['Age']) & (df_test['Age'] < 60), 'Age_cat'] = 5
df_test.loc[(60 <= df_test['Age']) & (df_test['Age'] < 70), 'Age_cat'] = 6
df_test.loc[(70 <= df_test['Age']), 'Age_cat'] = 7

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket      Fare Cabin Embarked  FamilySize Initial  \
# 0      0         A/5 21171  1.981001   NaN        S           2      Mr
# 1      0          PC 17599  4.266662   C85        C           2     Mrs
# 2      0  STON/O2. 3101282  2.070022   NaN        S           1    Miss
# ...

# %%
def category_age(x):
    if x < 10:
        return 0
    elif x < 20:
        return 1
    elif x < 30:
        return 2
    elif x < 40:
        return 3
    elif x < 50:
        return 4
    elif x < 60:
        return 5
    elif x < 70:
        return 6
    else:
        return 7

# %%
df_train['Age_cat_2'] = df_train['Age'].apply(category_age)

# %%
(df_train['Age_cat'] == df_train['Age_cat_2']).all()
# Out:
# True

# %%
df_train.drop(['Age', 'Age_cat_2'], axis=1, inplace=True) # axis는 세로로 컬럼이 날아감
df_test.drop(['Age'], axis=1, inplace=True)

# %%
# Mr, Mrs 같은 문자는 컴퓨터가 인식하기 어려움. -> 학습이 잘 안됨
# 숫자로 변경 필요

df_train.Initial.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Other'], dtype=object)

# %%
#df_train.loc[df_train['Initial'] == 'Master', 'Initial'] = 1
df_train['Initial'] = df_train['Initial'].map({'Master': 0, "Miss": 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})
df_test['Initial'] = df_test['Initial'].map({'Master': 0, "Miss": 1, 'Mr': 2, 'Mrs': 3, 'Other': 4})

# %%
type(df_train.Embarked.unique())
# Out:
# numpy.ndarray

# %%
type(df_train['Embarked'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df_train['Embarked'] = df_train['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})
df_test['Embarked'] = df_test['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    male      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female      1      0
# 2                             Heikkinen, Miss. Laina  female      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female      1      0
# 4                           Allen, Mr. William Henry    male      0      0
#
#              Ticket      Fare Cabin  Embarked  FamilySize  Initial  Age_cat
# 0         A/5 21171  1.981001   NaN         2           2        2        2
# 1          PC 17599  4.266662   C85         0           2        3        3
# 2  STON/O2. 3101282  2.070022   NaN         2           1        1        2
# ...

# %%
df_train.Embarked.isnull().any()
# Out:
# False

# %%
df_train['Sex'] = df_train['Sex'].map({'female': 0, 'male': 1})
df_test['Sex'] = df_test['Sex'].map({'female': 0, 'male': 1})

# %%
# Pearson coefficient => r (상관계수)
heatmap_data = df_train[['Survived', 'Pclass', 'Sex', 'Fare', 'Embarked', 'FamilySize', 'Initial', 'Age_cat']]

# %%
heatmap_data.corr()
# Out:
#             Survived    Pclass       Sex      Fare  Embarked  FamilySize  \
# Survived    1.000000 -0.338481 -0.543351  0.331805 -0.167675    0.016639
# Pclass     -0.338481  1.000000  0.131900 -0.670489  0.162098    0.065997
# Sex        -0.543351  0.131900  1.000000 -0.264751  0.108262   -0.200988
# Fare        0.331805 -0.670489 -0.264751  1.000000 -0.199932    0.389193
# Embarked   -0.167675  0.162098  0.108262 -0.199932  1.000000    0.066516
# FamilySize  0.016639  0.065997 -0.200988  0.389193  0.066516    1.000000
# Initial    -0.085529 -0.133054  0.051687 -0.019889  0.026550   -0.204574
# Age_cat    -0.095002 -0.314809  0.122917  0.077791 -0.033173   -0.280537
#
#              Initial   Age_cat
# Survived   -0.085529 -0.095002
# Pclass     -0.133054 -0.314809
# Sex         0.051687  0.122917
# Fare       -0.019889  0.077791
# Embarked    0.026550 -0.033173
# FamilySize -0.204574 -0.280537
# Initial     1.000000  0.481309
# Age_cat     0.481309  1.000000

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14, 12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths=0.1, vmax=1.0,
           square=True, cmap=colormap, linecolor='black', annot=True, annot_kws={'size': 16}, fmt='.3f') # float으로 캐스팅 후 상관계수 구하기
# Out:
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %% [markdown]
# ### Feature engineering - One-hot encoding
# 수치화시킨 카테고리 데이터를 그대로 넣어도 되지만, 모델의 성능을 높이기 위해 one-hot encoding을 해줄 수 있다.
# 카테고리 데이터를 잘 쓸 수 있게 바꿔주기
# ![image.png](attachment:e17ad2de-a0ed-4c52-a944-eaf119affa1f.png)
# - master가 맞으면 Initial_Master에 1, 아니면 0
# - 이렇게 컬럼을 바꾸면 질문이 명확하게 바뀌고 정보가 드러나게 된다. => 명목형이기 때문에 순서가 아니라 Binary 정보가 중요한 것임.

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name  Sex  \
# 0          892       3                              Kelly, Mr. James    1
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)    0
# 2          894       2                     Myles, Mr. Thomas Francis    1
# 3          895       3                              Wirz, Mr. Albert    1
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    0
#
#    SibSp  Parch   Ticket     Fare Cabin  Embarked  FamilySize  Initial  \
# 0      0      0   330911   7.8292   NaN         1           1        2
# 1      1      0   363272   7.0000   NaN         2           2        3
# 2      0      0   240276   9.6875   NaN         1           1        2
# 3      0      0   315154   8.6625   NaN         2           1        2
# 4      1      1  3101298  12.2875   NaN         2           3        3
#
#    Age_cat
# 0      3.0
# 1      4.0
# 2      6.0
# 3      2.0
# 4      2.0

# %%
df_train = pd.get_dummies(df_train, columns=['Initial'], prefix='Initial')
df_test = pd.get_dummies(df_test, columns=['Initial'], prefix='Initial')

# %%
df_train = pd.get_dummies(df_train, columns=['Embarked'], prefix='Embarked')
df_test = pd.get_dummies(df_test, columns=['Embarked'], prefix='Embarked')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0      1      0
# 4                           Allen, Mr. William Henry    1      0      0
#
#              Ticket      Fare Cabin  FamilySize  Age_cat  Initial_0  \
# 0         A/5 21171  1.981001   NaN           2        2      False
# 1          PC 17599  4.266662   C85           2        3      False
# 2  STON/O2. 3101282  2.070022   NaN           1        2      False
# ...

# %%
df_train.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)
df_test.drop(['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin'], axis=1, inplace=True)

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex      Fare  FamilySize  Age_cat  Initial_0  Initial_1  \
# 0         0       3    1  1.981001           2        2      False      False
# 1         1       1    0  4.266662           2        3      False      False
# 2         1       3    0  2.070022           1        2      False       True
# 3         1       1    0  3.972177           2        3      False      False
# 4         0       3    1  2.085672           1        3      False      False
#
#    Initial_2  Initial_3  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0       True      False      False       False       False        True
# 1      False       True      False        True       False       False
# 2      False      False      False       False       False        True
# 3      False       True      False       False       False        True
# 4       True      False      False       False       False        True

# %%
df_test.head()
# Out:
#    Pclass  Sex     Fare  FamilySize  Age_cat  Initial_0  Initial_1  Initial_2  \
# 0       3    1   7.8292           1      3.0      False      False       True
# 1       3    0   7.0000           2      4.0      False      False      False
# 2       2    1   9.6875           1      6.0      False      False       True
# 3       3    1   8.6625           1      2.0      False      False       True
# 4       3    0  12.2875           3      2.0      False      False      False
#
#    Initial_3  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0      False      False       False        True       False
# 1       True      False       False       False        True
# 2      False      False       False        True       False
# 3      False      False       False       False        True
# 4       True      False       False       False        True

# %% [markdown]
# # Model development - Machine Learning

# %%
df_test.loc[df_test['Fare'].isnull(), 'Fare'] = df_train['Fare'].mean()

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics # 모델을 평가하는 편리한 함수들 제공
from sklearn.model_selection import train_test_split

# %%
X_train = df_train.drop('Survived', axis=1).values
target_label = df_train['Survived'].values
X_test = df_test.values

# %%
X_tr, X_vld, y_tr, y_vld = train_test_split(X_train, target_label, test_size=0.3, random_state=2018)
# train과 test set 분할

# %%
model = RandomForestClassifier() # 모델 만들고
model.fit(X_tr, y_tr) # 학습
# Out:
# RandomForestClassifier()

# %%
prediction = model.predict(X_vld)

# %%
print('총 {}명 중 {:.2f}% 정확도로 생존 맞춤'.format(y_vld.shape[0], 100*metrics.accuracy_score(prediction, y_vld)))
# Out:
# 총 268명 중 82.84% 정확도로 생존 맞춤

# %% [markdown]
# ![image.png](attachment:118d2e97-1255-40e1-8624-b65f590600c9.png)

# %%
model.feature_importances_
# Out:
# array([0.10162162, 0.10477244, 0.33028992, 0.09367721, 0.12057347,
#        0.01075077, 0.03974363, 0.12491409, 0.02718779, 0.00416374,
#        0.01355657, 0.01226072, 0.01648802])

# %%
df_train.head()
# Out:
#    Survived  Pclass  Sex      Fare  FamilySize  Age_cat  Initial_0  Initial_1  \
# 0         0       3    1  1.981001           2        2      False      False
# 1         1       1    0  4.266662           2        3      False      False
# 2         1       3    0  2.070022           1        2      False       True
# 3         1       1    0  3.972177           2        3      False      False
# 4         0       3    1  2.085672           1        3      False      False
#
#    Initial_2  Initial_3  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0       True      False      False       False       False        True
# 1      False       True      False        True       False       False
# 2      False      False      False       False       False        True
# 3      False       True      False       False       False        True
# 4       True      False      False       False       False        True

# %%
from pandas import Series

# %%
X_train[0]
# Out:
# array([3, 1, 1.9810014688665833, 2, 2, False, False, True, False, False,
#        False, False, True], dtype=object)

# %%
df_test.head()
# Out:
#    Pclass  Sex     Fare  FamilySize  Age_cat  Initial_0  Initial_1  Initial_2  \
# 0       3    1   7.8292           1      3.0      False      False       True
# 1       3    0   7.0000           2      4.0      False      False      False
# 2       2    1   9.6875           1      6.0      False      False       True
# 3       3    1   8.6625           1      2.0      False      False       True
# 4       3    0  12.2875           3      2.0      False      False      False
#
#    Initial_3  Initial_4  Embarked_0  Embarked_1  Embarked_2
# 0      False      False       False        True       False
# 1       True      False       False       False        True
# 2      False      False       False        True       False
# 3      False      False       False       False        True
# 4       True      False       False       False        True

# %%
feature_importance = model.feature_importances_
Series_feat_imp = Series(feature_importance, index=df_test.columns)

# %%
plt.figure(figsize=(8, 8))
Series_feat_imp.sort_values(ascending=True).plot.barh()
plt.xlabel('Feature importance')
plt.ylabel('Feature')
plt.show()

# %%
submission = pd.read_csv('../input/titanic/gender_submission.csv')

# %%
submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
prediction = model.predict(X_test)

# %%
submission['Survived'] = prediction

# %%
submission.to_csv('./my_first_submission.csv', index=False)
